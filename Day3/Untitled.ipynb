# %%
import pandas as pd
import numpy as np

# %%
d = [
    {"name": "Amit", "address": "Mumbai", "birth_year": 1998 },
    {"name": "Ivy", "address": "Parlitian", "birth_year": 1992 },
    {"name": "Gusty", "address": "Kajiado", "birth_year": 1982 },
    {"name": "Alexia", "address": "Pivijay", "birth_year": 1975 },
    {"name": "Ophelia", "address": "Tatsuno", "birth_year": 1989 },
    {"name": "Annabelle", "address": "Velingrad", "birth_year": 2006 },
    {"name": "Marty", "address": "Somita", "birth_year": 1998 },
    {"name": "Sheelagh", "address": "Nastola", "birth_year": 2002 },
    {"name": "Zorina", "address": "Tong'an", "birth_year": 2010 },
    {"name": "Nobe", "address": "Guapore", "birth_year": 2003 },
]

# %%
d
# Out:
# [{'name': 'Amit', 'address': 'Mumbai', 'birth_year': 1998},
#  {'name': 'Ivy', 'address': 'Parlitian', 'birth_year': 1992},
#  {'name': 'Gusty', 'address': 'Kajiado', 'birth_year': 1982},
#  {'name': 'Alexia', 'address': 'Pivijay', 'birth_year': 1975},
#  {'name': 'Ophelia', 'address': 'Tatsuno', 'birth_year': 1989},
#  {'name': 'Annabelle', 'address': 'Velingrad', 'birth_year': 2006},
#  {'name': 'Marty', 'address': 'Somita', 'birth_year': 1998},
#  {'name': 'Sheelagh', 'address': 'Nastola', 'birth_year': 2002},
#  {'name': 'Zorina', 'address': "Tong'an", 'birth_year': 2010},
#  {'name': 'Nobe', 'address': 'Guapore', 'birth_year': 2003}]

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#         name    address  birth_year
# 0       Amit     Mumbai        1998
# 1        Ivy  Parlitian        1992
# 2      Gusty    Kajiado        1982
# 3     Alexia    Pivijay        1975
# 4    Ophelia    Tatsuno        1989
# 5  Annabelle  Velingrad        2006
# 6      Marty     Somita        1998
# 7   Sheelagh    Nastola        2002
# 8     Zorina    Tong'an        2010
# 9       Nobe    Guapore        2003

# %%
df[df['birth_year'] > 1992]
# Out:
#         name    address  birth_year
# 0       Amit     Mumbai        1998
# 5  Annabelle  Velingrad        2006
# 6      Marty     Somita        1998
# 7   Sheelagh    Nastola        2002
# 8     Zorina    Tong'an        2010
# 9       Nobe    Guapore        2003

# %%
df.filter(items=['name', 'address'])
# Out:
#         name    address
# 0       Amit     Mumbai
# 1        Ivy  Parlitian
# 2      Gusty    Kajiado
# 3     Alexia    Pivijay
# 4    Ophelia    Tatsuno
# 5  Annabelle  Velingrad
# 6      Marty     Somita
# 7   Sheelagh    Nastola
# 8     Zorina    Tong'an
# 9       Nobe    Guapore

# %%
filter_birth = df[df['birth_year'] > 1992]

# %%
l_birth = filter_birth.to_dict('records')

# %%
l_birth
# Out:
# [{'name': 'Amit', 'address': 'Mumbai', 'birth_year': 1998},
#  {'name': 'Annabelle', 'address': 'Velingrad', 'birth_year': 2006},
#  {'name': 'Marty', 'address': 'Somita', 'birth_year': 1998},
#  {'name': 'Sheelagh', 'address': 'Nastola', 'birth_year': 2002},
#  {'name': 'Zorina', 'address': "Tong'an", 'birth_year': 2010},
#  {'name': 'Nobe', 'address': 'Guapore', 'birth_year': 2003}]

# %%
d2 = [
    {"name": "Wayne", "address": "Obryte", "birth_year": 1985 },
    {"name": "Carlotta", "address": "Margoyoso", "birth_year": 1993 },
]

# %%
df2 = pd.DataFrame(d2)

# %%
df2
# Out:
#        name    address  birth_year
# 0     Wayne     Obryte        1985
# 1  Carlotta  Margoyoso        1993

# %%
new_df = pd.concat([df, df2], ignore_index=True)

# %%
new_df
# Out:
#          name    address  birth_year
# 0        Amit     Mumbai        1998
# 1         Ivy  Parlitian        1992
# 2       Gusty    Kajiado        1982
# 3      Alexia    Pivijay        1975
# 4     Ophelia    Tatsuno        1989
# 5   Annabelle  Velingrad        2006
# 6       Marty     Somita        1998
# 7    Sheelagh    Nastola        2002
# 8      Zorina    Tong'an        2010
# 9        Nobe    Guapore        2003
# 10      Wayne     Obryte        1985
# 11   Carlotta  Margoyoso        1993

# %%
new_df['name'] = new_df['name'].replace(['Wayne'], 'Dwayne')

# %%
new_df
# Out:
#          name    address  birth_year
# 0        Amit     Mumbai        1998
# 1         Ivy  Parlitian        1992
# 2       Gusty    Kajiado        1982
# 3      Alexia    Pivijay        1975
# 4     Ophelia    Tatsuno        1989
# 5   Annabelle  Velingrad        2006
# 6       Marty     Somita        1998
# 7    Sheelagh    Nastola        2002
# 8      Zorina    Tong'an        2010
# 9        Nobe    Guapore        2003
# 10     Dwayne     Obryte        1985
# 11   Carlotta  Margoyoso        1993

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#         name    address  birth_year
# 0       Amit     Mumbai        1998
# 1        Ivy  Parlitian        1992
# 2      Gusty    Kajiado        1982
# 3     Alexia    Pivijay        1975
# 4    Ophelia    Tatsuno        1989
# 5  Annabelle  Velingrad        2006
# 6      Marty     Somita        1998
# 7   Sheelagh    Nastola        2002
# 8     Zorina    Tong'an        2010
# 9       Nobe    Guapore        2003
